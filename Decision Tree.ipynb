# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
df=pd.read_csv("/Users/student/Downloads/DECISIONTREE - Sheet1.csv")
print(df)
d={'UK':0,'USA':1,'N':2}
df['Nationality']=df['Nationality'].map(d)
d={'YES':1,'NO':0}
df['Go']=df['Go'].map(d)
features=['Age','Experience','Rank','Nationality']
X=df[features]
y=df['Go']
dtree=DecisionTreeClassifier()
dtree=dtree.fit(X,y)
tree.plot_tree(dtree,feature_names=features)
plt.show()
# Out:
#    s no  Age  Experience  Rank Nationality   Go
# 0     1   36          12     9          UK   NO
# 1     2   42           7     6         USA   NO
# 2     3   64          11     2           N   NO
# 3     4   22           3     5         USA   NO
# 4     5   34          21     8         USA  YES
# 5     6   23           7     5          UK   NO
# 6     7   27           6     3           N  YES
# 7     8   43           3     5          UK  YES
# 8     9   23           3     6           N  YES
# 9    10   55           9     8           N  YES
